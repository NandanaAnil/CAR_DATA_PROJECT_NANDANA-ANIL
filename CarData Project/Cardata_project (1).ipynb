# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn import metrics

# %%
car_price = pd.read_csv('cardata.csv')
car_price
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
#To find the number of rows and columns of the dataset
car_price.shape
# Out:
# (301, 9)

# %%
car_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
car_price.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# ...

# %%
car_price.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
car_price.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
car_price.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='Year', y='Selling_Price', data = car_price, color = 'green')
plt.title('Car Data')
plt.xlabel('Year')
plt.ylabel('Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(14,7))
sns.barplot(x='Year', y='Present_Price', data = car_price, color = 'orange')
plt.title('Car Data with respect to price')
plt.xlabel('Year')
plt.ylabel('Present Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
selling_count = car_price['Year'].value_counts()
print(selling_count)
# Out:
# Year
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2006     4
# 2005     4
# 2003     2
# 2007     2
# 2018     1
# 2004     1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14,7))
sns.countplot(x='Year', data = car_price, palette = 'pastel')
plt.title('Car sold')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_4512\1167989463.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Year', data = car_price, palette = 'pastel')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(x='Selling_Price', y = 'Present_Price', data = car_price, palette = 'Set1')
plt.title('Selling price vs Present Price')
plt.xlabel('Selling Price')
plt.ylabel('Present Price')
plt.show()
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_4512\3358992439.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='Selling_Price', y = 'Present_Price', data = car_price, palette = 'Set1')

# %%
car_price['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
#Replacing 
car_price.replace({'Fuel_Type':{'Petrol':0, 'Diesel':1, 'CNG':2}}, inplace = True)
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_4512\3486937724.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price.replace({'Fuel_Type':{'Petrol':0, 'Diesel':1, 'CNG':2}}, inplace = True)

# %%
car_price.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
car_price['Seller_Type'].value_counts()
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
car_price.replace({'Seller_Type':{'Dealer':0, 'Individual':1}}, inplace = True)
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_4512\3132408930.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price.replace({'Seller_Type':{'Dealer':0, 'Individual':1}}, inplace = True)

# %%
car_price.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Seller_Type Transmission  Owner
# 0            0       Manual      0
# 1            0       Manual      0
# 2            0       Manual      0
# 3            0       Manual      0
# 4            0       Manual      0

# %%
car_price['Transmission'].value_counts()
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
car_price.replace({'Transmission':{'Manual':0, 'Automatic':1}}, inplace = True)
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_4512\3124819679.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price.replace({'Transmission':{'Manual':0, 'Automatic':1}}, inplace = True)

# %%
car_price.head(50)
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0            ritz  2014           3.35           5.59       27000          0
# 1             sx4  2013           4.75           9.54       43000          1
# 2            ciaz  2017           7.25           9.85        6900          0
# 3         wagon r  2011           2.85           4.15        5200          0
# 4           swift  2014           4.60           6.87       42450          1
# 5   vitara brezza  2018           9.25           9.83        2071          1
# 6            ciaz  2015           6.75           8.12       18796          0
# 7         s cross  2015           6.50           8.61       33429          1
# 8            ciaz  2016           8.75           8.89       20273          1
# 9            ciaz  2015           7.45           8.92       42367          1
# 10       alto 800  2017           2.85           3.60        2135          0
# ...

# %%
car_price = car_price.drop('Car_Name', axis = 1)

# %%
car_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           301 non-null    int64
#  1   Selling_Price  301 non-null    float64
#  2   Present_Price  301 non-null    float64
#  3   Kms_Driven     301 non-null    int64
#  4   Fuel_Type      301 non-null    int64
#  5   Seller_Type    301 non-null    int64
#  6   Transmission   301 non-null    int64
#  7   Owner          301 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 18.9 KB

# %%
#Correlation 
correlation = car_price.corr()
correlation
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# Year           1.000000       0.236141      -0.047584   -0.524342   0.053643
# Selling_Price  0.236141       1.000000       0.878983    0.029187   0.509467
# Present_Price -0.047584       0.878983       1.000000    0.203647   0.440415
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000   0.166801
# Fuel_Type      0.053643       0.509467       0.440415    0.166801   1.000000
# Seller_Type   -0.039896      -0.550724      -0.512030   -0.101419  -0.352415
# Transmission  -0.000394       0.367128       0.348715    0.162510   0.080466
# Owner         -0.182104      -0.088344       0.008057    0.089216  -0.055705
#
#                Seller_Type  Transmission     Owner
# Year             -0.039896     -0.000394 -0.182104
# Selling_Price    -0.550724      0.367128 -0.088344
# Present_Price    -0.512030      0.348715  0.008057
# Kms_Driven       -0.101419      0.162510  0.089216
# ...

# %%
sns.heatmap(correlation, cbar=True, square=True, fmt='.2f', annot=True, annot_kws={'size':8},cmap='viridis')
# Out:
# <Axes: >

# %%
x = car_price.drop('Selling_Price',axis=1)
x
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 0    2014           5.59       27000          0            0             0
# 1    2013           9.54       43000          1            0             0
# 2    2017           9.85        6900          0            0             0
# 3    2011           4.15        5200          0            0             0
# 4    2014           6.87       42450          1            0             0
# ..    ...            ...         ...        ...          ...           ...
# 296  2016          11.60       33988          1            0             0
# 297  2015           5.90       60000          0            0             0
# 298  2009          11.00       87934          0            0             0
# 299  2017          12.50        9000          1            0             0
# 300  2016           5.90        5464          0            0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# ...

# %%
y = car_price['Selling_Price']
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
x.shape, x_train.shape, x_test.shape, y_train.shape, y_test.shape, y.shape
# Out:
# ((301, 7), (240, 7), (61, 7), (240,), (61,), (301,))

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
training_data_predict = model.predict(x_train)
training_data_accuracy = metrics.r2_score(training_data_predict, y_train)
print('Accuracy of training data:', training_data_accuracy)
# Out:
# Accuracy of training data: 0.8687518544775662

# %%
testing_data_predict = model.predict(x_test)
testing_data_accuracy = metrics.r2_score(testing_data_predict, y_test)
print('Accuracy of testing data:', testing_data_accuracy)
# Out:
# Accuracy of testing data: 0.7881496929415209

# %%
plt.scatter(training_data_predict, y_train, color = 'blue')
plt.xlabel('predicted price')
plt.ylabel('actual price')
plt.title('predicted price vs actual price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(testing_data_predict, y_test, color = 'blue')
plt.xlabel('predicted price of test')
plt.ylabel('actual price of test')
plt.title('predicted price vs actual price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
input_data = (2014, 5.59, 27000, 1, 0, 0, 0)
input_data_as_np = np.asarray(input_data)
input_data_reshaped = input_data_as_np.reshape(1, -1)
prediction = model.predict(input_data_reshaped)
print('Predicted price of car:', prediction[0])
# Out:
# Predicted price of car: 5.2876892500597705
# C:\Users\Nandana\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
input_data = (2017, 9.85, 6900, 0, 0, 0, 0)
input_data_as_np = np.asarray(input_data)
input_data_reshaped = input_data_as_np.reshape(1, -1)
prediction = model.predict(input_data_reshaped)
print('Predicted price of car:', prediction[0])
# Out:
# Predicted price of car: 7.038703186574594
# C:\Users\Nandana\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
car_price.head(50)
# Out:
#     Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0   2014           3.35           5.59       27000          0            0
# 1   2013           4.75           9.54       43000          1            0
# 2   2017           7.25           9.85        6900          0            0
# 3   2011           2.85           4.15        5200          0            0
# 4   2014           4.60           6.87       42450          1            0
# 5   2018           9.25           9.83        2071          1            0
# 6   2015           6.75           8.12       18796          0            0
# 7   2015           6.50           8.61       33429          1            0
# 8   2016           8.75           8.89       20273          1            0
# 9   2015           7.45           8.92       42367          1            0
# 10  2017           2.85           3.60        2135          0            0
# ...
